# %%
# Import the modules
import pandas as pd
from pathlib import Path
import hvplot.pandas
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Import the K-means algorithm
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("okcupid_profiles.csv")
df.head()
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  ...  \
# 0         asian, white  ...
# 1                white  ...
# 2                  NaN  ...
# 3                white  ...
# 4  asian, black, other  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# 4  creating imagery to look at: http://bagsbrown....
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
# 3                  socially awkward but i do my best
# 4            i smile a lot and my inquisitive nature
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
# 3  bataille, celine, beckett. . . lynch, jarmusch...
# 4  music: bands, rappers, musicians at the moment...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
# 3                                                NaN
# 4                                                NaN
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
# 3   cats and german philosophy
# 4                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
# 3                              you feel so inclined.
# 4                                                NaN
#
# [5 rows x 31 columns]

# %%
service_ratings_df.hvplot.scatter(
    x="mobile_app_rating", 
    y="personal_banker_rating"
)

# %%
df.loc[(df.age == 110)|(df.age == 109), 'age'] = round(df[df.age < 100].age.mean(),0)

plt.hist(df.age, color="#5e3a98", bins=np.arange(15, 71, step=5))
plt.xlabel("age")
plt.show()

# %%
df2 = pd.read_csv("no_null_data.csv")
df2.head()
# Out:
#    age  status sex orientation       body_type               diet    drinks  \
# 0   22  single   m    straight  a little extra  strictly anything  socially
# 1   33  single   m    straight        athletic    mostly anything  socially
# 2   30  single   m    straight             fit    mostly anything  socially
# 3   29  single   m    straight             fit    mostly anything  socially
# 4   31  single   f    straight           curvy           anything  socially
#
#        drugs                          education     ethnicity  ...  \
# 0      never      working on college/university  asian, white  ...
# 1      never     graduated from masters program         white  ...
# 2      never  graduated from college/university         white  ...
# 3  sometimes  graduated from college/university         white  ...
# 4  sometimes     graduated from masters program         white  ...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  i left my comfort zone far behind in europe, a...
# 2  i'm a supply and demand manager for a sustaina...
# 3                                          living it
# 4  presently, holyshitwhatamidoinghere and the sp...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  listening, connecting emotionally, analyzing t...
# 2  making predictions, planning anything (i'm pre...
# 3                                         everything
# 4  algebra, alliteration, big spoon and little sp...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1  cheerful, open, curious, direct, active, sport...
# 2        that i'm smiling. pretty much at all times.
# 3                        i honestly couldn't say....
# 4  i look a lot like that chick you banged your f...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  the art of happiness by dalai lama, how findin...
# 2  a confederacy of dunces and infinite jest are ...
# 3  -books: anything joseph campbell - osho - terr...
# 4                - wikipedia - yes - yes - yes - yes
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  juicy fruit, water, swimming workouts, yoga pr...
# 2  1) sf restaurants, could they be any better? 2...
# 3                                   invalid question
# 4  civility, hope, basic arithmetic, any of the v...
#
#                                               essay6  \
# 0                        duality and humorous things
# 1            my passions and searching for new ones.
# 2  how to build an empire and a legacy. so far th...
# 3                                          the world
# 4  macros. also, puppies. i worry about the futur...
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1  having dinner and a night out with my close fr...
# 2  having beers with any number of friends and pr...
# 3                                               out.
# 4                  home, high, and doing the dishes.
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i'm pretty direct, so you can ask and i'll tel...
# 2  when i was a kid i thought steven segal was re...
# 3                                                 no
# 4  i'm terrible at small talk which makes for awk...
#
#                                               essay9  zodiac_sign
# 0  you want to be swept off your feet! you are ti...       gemini
# 1                                 you wanna meet up.       pisces
# 2  you're a positive and creative personality loo...  sagittarius
# 3                                    you're curious.        libra
# 4                      you find challenge rewarding.       pisces
#
# [5 rows x 31 columns]
