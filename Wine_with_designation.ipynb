# %%
import pandas as pd
from pycaret.classification import *

df = pd.read_csv("desc_designation_data_CLEAN.csv")
data = df[['wine_type','designation','description']]

d = data.sample(1000)
exp1 = setup(d, target='wine_type',text_features=['description'],text_features_method='tf-idf',session_id=123)
# Out:
# <style type="text/css">
# #T_92e20_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_92e20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92e20_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_92e20_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92e20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92e20_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_92e20_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92e20_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_92e20_row1_col1" class="data row1 col1" >wine_type</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92e20_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_92e20_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92e20_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_92e20_row3_col1" class="data row3 col1" >other: 0, red: 1, white: 2</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92e20_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_92e20_row4_col1" class="data row4 col1" >(1000, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92e20_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_92e20_row5_col1" class="data row5 col1" >(1000, 3629)</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92e20_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_92e20_row6_col1" class="data row6 col1" >(700, 3629)</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92e20_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_92e20_row7_col1" class="data row7 col1" >(300, 3629)</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_92e20_row8_col0" class="data row8 col0" >Text features</td>
#       <td id="T_92e20_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_92e20_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_92e20_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_92e20_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_92e20_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_92e20_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_92e20_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_92e20_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_92e20_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_92e20_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_92e20_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_92e20_row14_col0" class="data row14 col0" >Text features embedding method</td>
#       <td id="T_92e20_row14_col1" class="data row14 col1" >tf-idf</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_92e20_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_92e20_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_92e20_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_92e20_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_92e20_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_92e20_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_92e20_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_92e20_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_92e20_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_92e20_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_92e20_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_92e20_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_92e20_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_92e20_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_92e20_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_92e20_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_92e20_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_92e20_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_92e20_row23_col1" class="data row23 col1" >e8ad</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('X_train_transformed')
# Out:
#        designation  description_000  description_07  description_09  \
# 17548     1.165279              0.0             0.0             0.0
# 22145     1.242074              0.0             0.0             0.0
# 37043     1.284070              0.0             0.0             0.0
# 33050     1.165279              0.0             0.0             0.0
# 49507     1.165279              0.0             0.0             0.0
# ...            ...              ...             ...             ...
# 27443     1.165279              0.0             0.0             0.0
# 39947     1.295388              0.0             0.0             0.0
# 40631     1.176031              0.0             0.0             0.0
# 22512     1.295388              0.0             0.0             0.0
# 35029     1.165279              0.0             0.0             0.0
#
#        description_10  description_100  description_11  description_111  \
# 17548             0.0              0.0             0.0              0.0
# 22145             0.0              0.0             0.0              0.0
# 37043             0.0              0.0             0.0              0.0
# 33050             0.0              0.0             0.0              0.0
# 49507             0.0              0.0             0.0              0.0
# ...               ...              ...             ...              ...
# 27443             0.0              0.0             0.0              0.0
# 39947             0.0              0.0             0.0              0.0
# 40631             0.0              0.0             0.0              0.0
# 22512             0.0              0.0             0.0              0.0
# 35029             0.0              0.0             0.0              0.0
#
#        description_114  description_12  ...  description_zephyr  \
# 17548              0.0             0.0  ...                 0.0
# 22145              0.0             0.0  ...                 0.0
# 37043              0.0             0.0  ...                 0.0
# 33050              0.0             0.0  ...                 0.0
# 49507              0.0             0.0  ...                 0.0
# ...                ...             ...  ...                 ...
# 27443              0.0             0.0  ...                 0.0
# 39947              0.0             0.0  ...                 0.0
# 40631              0.0             0.0  ...                 0.0
# 22512              0.0             0.0  ...                 0.0
# 35029              0.0             0.0  ...                 0.0
#
#        description_zest  description_zesty  description_zin  \
# 17548               0.0                0.0              0.0
# 22145               0.0                0.0              0.0
# 37043               0.0                0.0              0.0
# 33050               0.0                0.0              0.0
# 49507               0.0                0.0              0.0
# ...                 ...                ...              ...
# 27443               0.0                0.0              0.0
# 39947               0.0                0.0              0.0
# 40631               0.0                0.0              0.0
# 22512               0.0                0.0              0.0
# 35029               0.0                0.0              0.0
#
#        description_zinfandel  description_zingy  description_zins  \
# 17548                    0.0                0.0               0.0
# 22145                    0.0                0.0               0.0
# 37043                    0.0                0.0               0.0
# 33050                    0.0                0.0               0.0
# 49507                    0.0                0.0               0.0
# ...                      ...                ...               ...
# 27443                    0.0                0.0               0.0
# 39947                    0.0                0.0               0.0
# 40631                    0.0                0.0               0.0
# 22512                    0.0                0.0               0.0
# 35029                    0.0                0.0               0.0
#
#        description_zippy  description_zips  description_zone
# 17548                0.0               0.0          0.297457
# 22145                0.0               0.0          0.000000
# 37043                0.0               0.0          0.000000
# 33050                0.0               0.0          0.000000
# 49507                0.0               0.0          0.000000
# ...                  ...               ...               ...
# 27443                0.0               0.0          0.000000
# 39947                0.0               0.0          0.000000
# 40631                0.0               0.0          0.000000
# 22512                0.0               0.0          0.000000
# 35029                0.0               0.0          0.000000
#
# [700 rows x 3628 columns]

# %%
best = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_fd6ef th {
#   text-align: left;
# }
# #T_fd6ef_row0_col0, #T_fd6ef_row0_col2, #T_fd6ef_row1_col0, #T_fd6ef_row1_col1, #T_fd6ef_row1_col2, #T_fd6ef_row1_col3, #T_fd6ef_row1_col4, #T_fd6ef_row1_col5, #T_fd6ef_row1_col6, #T_fd6ef_row1_col7, #T_fd6ef_row2_col0, #T_fd6ef_row2_col1, #T_fd6ef_row2_col2, #T_fd6ef_row2_col3, #T_fd6ef_row2_col4, #T_fd6ef_row2_col5, #T_fd6ef_row2_col6, #T_fd6ef_row2_col7, #T_fd6ef_row3_col0, #T_fd6ef_row3_col1, #T_fd6ef_row3_col2, #T_fd6ef_row3_col3, #T_fd6ef_row3_col4, #T_fd6ef_row3_col5, #T_fd6ef_row3_col6, #T_fd6ef_row3_col7, #T_fd6ef_row4_col0, #T_fd6ef_row4_col1, #T_fd6ef_row4_col2, #T_fd6ef_row4_col3, #T_fd6ef_row4_col4, #T_fd6ef_row4_col5, #T_fd6ef_row4_col6, #T_fd6ef_row4_col7, #T_fd6ef_row5_col0, #T_fd6ef_row5_col1, #T_fd6ef_row5_col2, #T_fd6ef_row5_col3, #T_fd6ef_row5_col4, #T_fd6ef_row5_col5, #T_fd6ef_row5_col6, #T_fd6ef_row5_col7, #T_fd6ef_row6_col0, #T_fd6ef_row6_col1, #T_fd6ef_row6_col3, #T_fd6ef_row6_col4, #T_fd6ef_row6_col5, #T_fd6ef_row6_col6, #T_fd6ef_row6_col7, #T_fd6ef_row7_col0, #T_fd6ef_row7_col1, #T_fd6ef_row7_col2, #T_fd6ef_row7_col3, #T_fd6ef_row7_col4, #T_fd6ef_row7_col5, #T_fd6ef_row7_col6, #T_fd6ef_row7_col7, #T_fd6ef_row8_col0, #T_fd6ef_row8_col1, #T_fd6ef_row8_col2, #T_fd6ef_row8_col3, #T_fd6ef_row8_col4, #T_fd6ef_row8_col5, #T_fd6ef_row8_col6, #T_fd6ef_row8_col7, #T_fd6ef_row9_col0, #T_fd6ef_row9_col1, #T_fd6ef_row9_col2, #T_fd6ef_row9_col3, #T_fd6ef_row9_col4, #T_fd6ef_row9_col5, #T_fd6ef_row9_col6, #T_fd6ef_row9_col7, #T_fd6ef_row10_col0, #T_fd6ef_row10_col1, #T_fd6ef_row10_col2, #T_fd6ef_row10_col3, #T_fd6ef_row10_col4, #T_fd6ef_row10_col5, #T_fd6ef_row10_col6, #T_fd6ef_row10_col7, #T_fd6ef_row11_col0, #T_fd6ef_row11_col1, #T_fd6ef_row11_col2, #T_fd6ef_row11_col3, #T_fd6ef_row11_col4, #T_fd6ef_row11_col5, #T_fd6ef_row11_col6, #T_fd6ef_row11_col7, #T_fd6ef_row12_col0, #T_fd6ef_row12_col1, #T_fd6ef_row12_col2, #T_fd6ef_row12_col3, #T_fd6ef_row12_col4, #T_fd6ef_row12_col5, #T_fd6ef_row12_col6, #T_fd6ef_row12_col7, #T_fd6ef_row13_col0, #T_fd6ef_row13_col1, #T_fd6ef_row13_col2, #T_fd6ef_row13_col3, #T_fd6ef_row13_col4, #T_fd6ef_row13_col5, #T_fd6ef_row13_col6, #T_fd6ef_row13_col7 {
#   text-align: left;
# }
# #T_fd6ef_row0_col1, #T_fd6ef_row0_col3, #T_fd6ef_row0_col4, #T_fd6ef_row0_col5, #T_fd6ef_row0_col6, #T_fd6ef_row0_col7, #T_fd6ef_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd6ef_row0_col8, #T_fd6ef_row1_col8, #T_fd6ef_row2_col8, #T_fd6ef_row3_col8, #T_fd6ef_row4_col8, #T_fd6ef_row5_col8, #T_fd6ef_row6_col8, #T_fd6ef_row7_col8, #T_fd6ef_row8_col8, #T_fd6ef_row9_col8, #T_fd6ef_row10_col8, #T_fd6ef_row12_col8, #T_fd6ef_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd6ef_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd6ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd6ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd6ef_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fd6ef_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fd6ef_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fd6ef_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fd6ef_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fd6ef_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fd6ef_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fd6ef_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd6ef_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_fd6ef_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_fd6ef_row0_col1" class="data row0 col1" >0.9314</td>
#       <td id="T_fd6ef_row0_col2" class="data row0 col2" >0.9859</td>
#       <td id="T_fd6ef_row0_col3" class="data row0 col3" >0.9314</td>
#       <td id="T_fd6ef_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_fd6ef_row0_col5" class="data row0 col5" >0.9176</td>
#       <td id="T_fd6ef_row0_col6" class="data row0 col6" >0.8001</td>
#       <td id="T_fd6ef_row0_col7" class="data row0 col7" >0.8099</td>
#       <td id="T_fd6ef_row0_col8" class="data row0 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ef_level0_row1" class="row_heading level0 row1" >svm</th>
#       <td id="T_fd6ef_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#       <td id="T_fd6ef_row1_col1" class="data row1 col1" >0.9029</td>
#       <td id="T_fd6ef_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_fd6ef_row1_col3" class="data row1 col3" >0.9029</td>
#       <td id="T_fd6ef_row1_col4" class="data row1 col4" >0.9006</td>
#       <td id="T_fd6ef_row1_col5" class="data row1 col5" >0.8862</td>
#       <td id="T_fd6ef_row1_col6" class="data row1 col6" >0.6891</td>
#       <td id="T_fd6ef_row1_col7" class="data row1 col7" >0.7233</td>
#       <td id="T_fd6ef_row1_col8" class="data row1 col8" >0.6920</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ef_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_fd6ef_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_fd6ef_row2_col1" class="data row2 col1" >0.8971</td>
#       <td id="T_fd6ef_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_fd6ef_row2_col3" class="data row2 col3" >0.8971</td>
#       <td id="T_fd6ef_row2_col4" class="data row2 col4" >0.8781</td>
#       <td id="T_fd6ef_row2_col5" class="data row2 col5" >0.8773</td>
#       <td id="T_fd6ef_row2_col6" class="data row2 col6" >0.6748</td>
#       <td id="T_fd6ef_row2_col7" class="data row2 col7" >0.7070</td>
#       <td id="T_fd6ef_row2_col8" class="data row2 col8" >0.7160</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ef_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_fd6ef_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_fd6ef_row3_col1" class="data row3 col1" >0.8929</td>
#       <td id="T_fd6ef_row3_col2" class="data row3 col2" >0.9820</td>
#       <td id="T_fd6ef_row3_col3" class="data row3 col3" >0.8929</td>
#       <td id="T_fd6ef_row3_col4" class="data row3 col4" >0.8723</td>
#       <td id="T_fd6ef_row3_col5" class="data row3 col5" >0.8734</td>
#       <td id="T_fd6ef_row3_col6" class="data row3 col6" >0.6633</td>
#       <td id="T_fd6ef_row3_col7" class="data row3 col7" >0.6942</td>
#       <td id="T_fd6ef_row3_col8" class="data row3 col8" >1.0200</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ef_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_fd6ef_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_fd6ef_row4_col1" class="data row4 col1" >0.8857</td>
#       <td id="T_fd6ef_row4_col2" class="data row4 col2" >0.9503</td>
#       <td id="T_fd6ef_row4_col3" class="data row4 col3" >0.8857</td>
#       <td id="T_fd6ef_row4_col4" class="data row4 col4" >0.8821</td>
#       <td id="T_fd6ef_row4_col5" class="data row4 col5" >0.8677</td>
#       <td id="T_fd6ef_row4_col6" class="data row4 col6" >0.6361</td>
#       <td id="T_fd6ef_row4_col7" class="data row4 col7" >0.6749</td>
#       <td id="T_fd6ef_row4_col8" class="data row4 col8" >2.4040</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ef_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_fd6ef_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_fd6ef_row5_col1" class="data row5 col1" >0.8457</td>
#       <td id="T_fd6ef_row5_col2" class="data row5 col2" >0.7013</td>
#       <td id="T_fd6ef_row5_col3" class="data row5 col3" >0.8457</td>
#       <td id="T_fd6ef_row5_col4" class="data row5 col4" >0.8294</td>
#       <td id="T_fd6ef_row5_col5" class="data row5 col5" >0.8157</td>
#       <td id="T_fd6ef_row5_col6" class="data row5 col6" >0.4836</td>
#       <td id="T_fd6ef_row5_col7" class="data row5 col7" >0.5394</td>
#       <td id="T_fd6ef_row5_col8" class=
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_95f43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95f43_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_95f43_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_95f43_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_95f43_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_95f43_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_95f43_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_95f43_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_95f43_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95f43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95f43_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_95f43_row0_col1" class="data row0 col1" >0.9233</td>
#       <td id="T_95f43_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_95f43_row0_col3" class="data row0 col3" >0.9233</td>
#       <td id="T_95f43_row0_col4" class="data row0 col4" >0.8989</td>
#       <td id="T_95f43_row0_col5" class="data row0 col5" >0.9088</td>
#       <td id="T_95f43_row0_col6" class="data row0 col6" >0.7760</td>
#       <td id="T_95f43_row0_col7" class="data row0 col7" >0.7878</td>
#     </tr>
#   </tbody>
# </table>

# %%
create_app(best)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
