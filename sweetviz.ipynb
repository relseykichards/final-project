# %%
import pandas as pd

# %%
df = pd.read_csv("no_null_data.csv")
df
# Out:
#       age  status sex orientation       body_type               diet  \
# 0      22  single   m    straight  a little extra  strictly anything
# 1      33  single   m    straight        athletic    mostly anything
# 2      30  single   m    straight             fit    mostly anything
# 3      29  single   m    straight             fit    mostly anything
# 4      31  single   f    straight           curvy           anything
# ...   ...     ...  ..         ...             ...                ...
# 4402   33  single   f    straight  a little extra       mostly other
# 4403   24  single   m    straight          skinny           anything
# 4404   29  single   f    straight    full figured    mostly anything
# 4405   24  single   m    straight             fit    mostly anything
# 4406   27  single   m    straight        athletic    mostly anything
#
#           drinks      drugs                          education     ethnicity  \
# ...

# %%
median_income = df['income'].median()
df['income'] = df['income'].replace(-1, median_income)
df['income']
# Out:
# 0          -1
# 1          -1
# 2          -1
# 3       40000
# 4          -1
#         ...
# 4402       -1
# 4403    20000
# 4404       -1
# 4405       -1
# 4406       -1
# Name: income, Length: 4407, dtype: int64

# %%
rows_with_minus_one = df[df['income'] == -1]
print(rows_with_minus_one)
# Out:
#       age  status sex orientation       body_type               diet  \
# 0      22  single   m    straight  a little extra  strictly anything
# 1      33  single   m    straight        athletic    mostly anything
# 2      30  single   m    straight             fit    mostly anything
# 4      31  single   f    straight           curvy           anything
# 5      45  single   f    straight             fit    mostly anything
# ...   ...     ...  ..         ...             ...                ...
# 4401   26  single   f    straight           curvy       mostly other
# 4402   33  single   f    straight  a little extra       mostly other
# 4404   29  single   f    straight    full figured    mostly anything
# 4405   24  single   m    straight             fit    mostly anything
# 4406   27  single   m    straight        athletic    mostly anything
#
#           drinks      drugs                          education  \
# 0       socially      never      working on college/university
# ...

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html()
# Out:
# /Users/patrycjapekala/anaconda3/lib/python3.10/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /Users/patrycjapekala/anaconda3/lib/python3.10/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
# Feature: age                                 |  | [  3%]   00:00 -> (00:02 left)/Users/patrycjapekala/anaconda3/lib/python3.10/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# ...
