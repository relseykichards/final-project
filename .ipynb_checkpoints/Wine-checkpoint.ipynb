# %%
data = df[['description','wine_type']]

# %%
import pandas as pd
from pycaret.classification import *

# df = pd.read_csv("Code Snippets/cleaned_wine_data.csv")
# data_short = df[0:1000]
data = df[['description','wine_type']]

d = data.sample(1000)
exp1 = setup(d, target='wine_type',text_features=['description'],text_features_method='tf-idf',session_id=123)
# Out:
# <style type="text/css">
# #T_983f8_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_983f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_983f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_983f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_983f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_983f8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_983f8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_983f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_983f8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_983f8_row1_col1" class="data row1 col1" >wine_type</td>
#     </tr>
#     <tr>
#       <th id="T_983f8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
get_config('X_train_transformed')
# Out:
#         description_000  description_07  description_08  description_10  \
# 110105              0.0             0.0             0.0             0.0
# 14315               0.0             0.0             0.0             0.0
# 82741               0.0             0.0             0.0             0.0
# 109618              0.0             0.0             0.0             0.0
# 38560               0.0             0.0             0.0             0.0
# ...                 ...             ...             ...             ...
# 32821               0.0             0.0             0.0             0.0
# 35166               0.0             0.0             0.0             0.0
# 64963               0.0             0.0             0.0             0.0
# 7240                0.0             0.0             0.0             0.0
# 103539              0.0             0.0             0.0             0.0
#
#         description_100  description_11  description_12  description_13  \
# ...

# %%
best = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_32dfe th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6e11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6e11_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f6e11_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f6e11_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f6e11_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f6e11_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f6e11_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f6e11_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f6e11_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6e11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6e11_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
# ...

# %%
create_app(best)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
